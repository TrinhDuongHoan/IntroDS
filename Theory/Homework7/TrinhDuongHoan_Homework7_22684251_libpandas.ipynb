# %% [markdown]
# ## $$\text{Bài tập sử dụng thư viện pandas trong python}$$

# %%
import pandas as pd

# %%
# Đọc dữ liệu từ file csv, excel, ...
col_names = [
    'Number of times pregnant',
    'Plasma glucose concentration',
    'Diastolic blood pressure',
    'Triceps skin fold thickness',
    '2-Hour serum insulin',
    'Body mass index',
    'Diabetes pedigree function',
    'Age',
    'Class'
]
filename = 'pima-indians-diabetes-Full_Description.csv'
data = pd.read_csv(filename,header= None, names=col_names)

# %%
# Ghi dữ liệu ra file csv, excel, ...
data.to_csv('new_data.csv', index=False)

# %%
# Xem và hiển thị dữ liệu
data.head()
# Out:
#    Number of times pregnant  Plasma glucose concentration  \
# 0                         6                           148
# 1                         1                            85
# 2                         8                           183
# 3                         1                            89
# 4                         0                           137
#
#    Diastolic blood pressure  Triceps skin fold thickness  \
# 0                        72                           35
# 1                        66                           29
# 2                        64                            0
# 3                        66                           23
# 4                        40                           35
#
#    2-Hour serum insulin  Body mass index  Diabetes pedigree function  Age  \
# 0                     0             33.6                       0.627   50
# 1                     0             26.6                       0.351   31
# ...

# %%
data.tail()
# Out:
#      Number of times pregnant  Plasma glucose concentration  \
# 763                        10                           101
# 764                         2                           122
# 765                         5                           121
# 766                         1                           126
# 767                         1                            93
#
#      Diastolic blood pressure  Triceps skin fold thickness  \
# 763                        76                           48
# 764                        70                           27
# 765                        72                           23
# 766                        60                            0
# 767                        70                           31
#
#      2-Hour serum insulin  Body mass index  Diabetes pedigree function  Age  \
# 763                   180             32.9                       0.171   63
# 764                     0             36.8                       0.340   27
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Number of times pregnant      768 non-null    int64
#  1   Plasma glucose concentration  768 non-null    int64
#  2   Diastolic blood pressure      768 non-null    int64
#  3   Triceps skin fold thickness   768 non-null    int64
#  4   2-Hour serum insulin          768 non-null    int64
#  5   Body mass index               768 non-null    float64
#  6   Diabetes pedigree function    768 non-null    float64
#  7   Age                           768 non-null    int64
#  8   Class                         768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
data.describe()
# Out:
#        Number of times pregnant  Plasma glucose concentration  \
# count                768.000000                    768.000000
# mean                   3.845052                    120.894531
# std                    3.369578                     31.972618
# min                    0.000000                      0.000000
# 25%                    1.000000                     99.000000
# 50%                    3.000000                    117.000000
# 75%                    6.000000                    140.250000
# max                   17.000000                    199.000000
#
#        Diastolic blood pressure  Triceps skin fold thickness  \
# count                768.000000                   768.000000
# mean                  69.105469                    20.536458
# std                   19.355807                    15.952218
# min                    0.000000                     0.000000
# 25%                   62.000000                     0.000000
# ...

# %%
# Lọc dữ liệu
data.query('Age > 30')
# Out:
#      Number of times pregnant  Plasma glucose concentration  \
# 0                           6                           148
# 1                           1                            85
# 2                           8                           183
# 4                           0                           137
# 8                           2                           197
# ..                        ...                           ...
# 759                         6                           190
# 761                         9                           170
# 762                         9                            89
# 763                        10                           101
# 766                         1                           126
#
#      Diastolic blood pressure  Triceps skin fold thickness  \
# 0                          72                           35
# 1                          66                           29
# 2                          64                            0
# ...

# %%
data.loc[0]
# Out:
# Number of times pregnant          6.000
# Plasma glucose concentration    148.000
# Diastolic blood pressure         72.000
# Triceps skin fold thickness      35.000
# 2-Hour serum insulin              0.000
# Body mass index                  33.600
# Diabetes pedigree function        0.627
# Age                              50.000
# Class                             1.000
# Name: 0, dtype: float64

# %%
data.iloc[1]
# Out:
# Number of times pregnant         1.000
# Plasma glucose concentration    85.000
# Diastolic blood pressure        66.000
# Triceps skin fold thickness     29.000
# 2-Hour serum insulin             0.000
# Body mass index                 26.600
# Diabetes pedigree function       0.351
# Age                             31.000
# Class                            0.000
# Name: 1, dtype: float64

# %%
data['Class'].isin([1])
# Out:
# 0       True
# 1      False
# 2       True
# 3      False
# 4       True
#        ...
# 763    False
# 764    False
# 765    False
# 766     True
# 767    False
# Name: Class, Length: 768, dtype: bool

# %%
# Sắp xếp dữ liệu
data.sort_values(by='Age')
# Out:
#      Number of times pregnant  Plasma glucose concentration  \
# 255                         1                           113
# 60                          2                            84
# 102                         0                           125
# 182                         1                             0
# 623                         0                            94
# ..                        ...                           ...
# 123                         5                           132
# 684                         5                           136
# 666                         4                           145
# 453                         2                           119
# 459                         9                           134
#
#      Diastolic blood pressure  Triceps skin fold thickness  \
# 255                        64                           35
# 60                          0                            0
# 102                        96                            0
# ...

# %%
data.sort_index(axis=0, ascending=False)
# Out:
#      Number of times pregnant  Plasma glucose concentration  \
# 767                         1                            93
# 766                         1                           126
# 765                         5                           121
# 764                         2                           122
# 763                        10                           101
# ..                        ...                           ...
# 4                           0                           137
# 3                           1                            89
# 2                           8                           183
# 1                           1                            85
# 0                           6                           148
#
#      Diastolic blood pressure  Triceps skin fold thickness  \
# 767                        70                           31
# 766                        60                            0
# 765                        72                           23
# ...

# %%
# Chọn cột và dòng
data.iloc[0, 0]
# Out:
# 6

# %%
# Xử lí dữ liệu thiếu
data.dropna()
# Out:
#      Number of times pregnant  Plasma glucose concentration  \
# 0                           6                           148
# 1                           1                            85
# 2                           8                           183
# 3                           1                            89
# 4                           0                           137
# ..                        ...                           ...
# 763                        10                           101
# 764                         2                           122
# 765                         5                           121
# 766                         1                           126
# 767                         1                            93
#
#      Diastolic blood pressure  Triceps skin fold thickness  \
# 0                          72                           35
# 1                          66                           29
# 2                          64                            0
# ...

# %%
data.fillna(value=0)
# Out:
#      Number of times pregnant  Plasma glucose concentration  \
# 0                           6                           148
# 1                           1                            85
# 2                           8                           183
# 3                           1                            89
# 4                           0                           137
# ..                        ...                           ...
# 763                        10                           101
# 764                         2                           122
# 765                         5                           121
# 766                         1                           126
# 767                         1                            93
#
#      Diastolic blood pressure  Triceps skin fold thickness  \
# 0                          72                           35
# 1                          66                           29
# 2                          64                            0
# ...

# %%
# Thực hiện phép toán
data.assign(test=data['Age'] * data['Class'])
# Out:
#      Number of times pregnant  Plasma glucose concentration  \
# 0                           6                           148
# 1                           1                            85
# 2                           8                           183
# 3                           1                            89
# 4                           0                           137
# ..                        ...                           ...
# 763                        10                           101
# 764                         2                           122
# 765                         5                           121
# 766                         1                           126
# 767                         1                            93
#
#      Diastolic blood pressure  Triceps skin fold thickness  \
# 0                          72                           35
# 1                          66                           29
# 2                          64                            0
# ...

# %%
data['Age'].apply(lambda x: 1 if x > 30 else 0)
# Out:
# 0      1
# 1      1
# 2      1
# 3      0
# 4      1
#       ..
# 763    1
# 764    0
# 765    0
# 766    1
# 767    0
# Name: Age, Length: 768, dtype: int64

# %%
mapping = {0: False, 1: True}
data['Age'].map(mapping)
# Out:
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
#       ...
# 763    NaN
# 764    NaN
# 765    NaN
# 766    NaN
# 767    NaN
# Name: Age, Length: 768, dtype: object

# %%
# Nhóm và tổng hợp dữ liệu
data[['Age', 'Class']].groupby(['Class']).hist()
# Out:
# Class
# 0    [[Axes(0.125,0.11;0.336957x0.77), Axes(0.56304...
# 1    [[Axes(0.125,0.11;0.336957x0.77), Axes(0.56304...
# dtype: object

# %%
data['Number of times pregnant'].sum()
# Out:
# 2953

# %%
data['Number of times pregnant'].mean()
# Out:
# 3.8450520833333335

# %%
data['Number of times pregnant'].count()
# Out:
# 768

# %%
# Kết hợp và nối dữ liệu
contact = pd.concat([data, data], axis=0)
contact
# Out:
#      Number of times pregnant  Plasma glucose concentration  \
# 0                           6                           148
# 1                           1                            85
# 2                           8                           183
# 3                           1                            89
# 4                           0                           137
# ..                        ...                           ...
# 763                        10                           101
# 764                         2                           122
# 765                         5                           121
# 766                         1                           126
# 767                         1                            93
#
#      Diastolic blood pressure  Triceps skin fold thickness  \
# 0                          72                           35
# 1                          66                           29
# 2                          64                            0
# ...

# %%
# Đổi tên và định dạng cột
data.rename(columns={'Age': 'Age (years)'}, inplace=True)
data
# Out:
#      Number of times pregnant  Plasma glucose concentration  \
# 0                           6                           148
# 1                           1                            85
# 2                           8                           183
# 3                           1                            89
# 4                           0                           137
# ..                        ...                           ...
# 763                        10                           101
# 764                         2                           122
# 765                         5                           121
# 766                         1                           126
# 767                         1                            93
#
#      Diastolic blood pressure  Triceps skin fold thickness  \
# 0                          72                           35
# 1                          66                           29
# 2                          64                            0
# ...

# %%
data['Class'] = data['Class'].astype(bool)
data
# Out:
#      Number of times pregnant  Plasma glucose concentration  \
# 0                           6                           148
# 1                           1                            85
# 2                           8                           183
# 3                           1                            89
# 4                           0                           137
# ..                        ...                           ...
# 763                        10                           101
# 764                         2                           122
# 765                         5                           121
# 766                         1                           126
# 767                         1                            93
#
#      Diastolic blood pressure  Triceps skin fold thickness  \
# 0                          72                           35
# 1                          66                           29
# 2                          64                            0
# ...

# %%
# Xóa dữ liệu
data.drop(columns='Age (years)', inplace=True)
data
# Out:
#      Number of times pregnant  Plasma glucose concentration  \
# 0                           6                           148
# 1                           1                            85
# 2                           8                           183
# 3                           1                            89
# 4                           0                           137
# ..                        ...                           ...
# 763                        10                           101
# 764                         2                           122
# 765                         5                           121
# 766                         1                           126
# 767                         1                            93
#
#      Diastolic blood pressure  Triceps skin fold thickness  \
# 0                          72                           35
# 1                          66                           29
# 2                          64                            0
# ...

# %%
data.drop(index=[0], inplace=True)
data
# Out:
#      Number of times pregnant  Plasma glucose concentration  \
# 1                           1                            85
# 2                           8                           183
# 3                           1                            89
# 4                           0                           137
# 5                           5                           116
# ..                        ...                           ...
# 763                        10                           101
# 764                         2                           122
# 765                         5                           121
# 766                         1                           126
# 767                         1                            93
#
#      Diastolic blood pressure  Triceps skin fold thickness  \
# 1                          66                           29
# 2                          64                            0
# 3                          66                           23
# ...

# %%
# Thao tác với thời gian
start_date = '2024-03-11'
end_date = '2024-03-28'
date_range = pd.date_range(start=start_date, end=end_date)

import numpy as np
dates = np.random.choice(date_range, size=767)

data['Date'] = dates
data
# Out:
#      Number of times pregnant  Plasma glucose concentration  \
# 1                           1                            85
# 2                           8                           183
# 3                           1                            89
# 4                           0                           137
# 5                           5                           116
# ..                        ...                           ...
# 763                        10                           101
# 764                         2                           122
# 765                         5                           121
# 766                         1                           126
# 767                         1                            93
#
#      Diastolic blood pressure  Triceps skin fold thickness  \
# 1                          66                           29
# 2                          64                            0
# 3                          66                           23
# ...

# %%
data['Date'].dt.day
# Out:
# 1      16
# 2      25
# 3      20
# 4      17
# 5      17
#        ..
# 763    12
# 764    17
# 765    20
# 766    28
# 767    20
# Name: Date, Length: 767, dtype: int32

# %%
# Vẽ biểu đồ
data['Number of times pregnant'].hist()
# Out:
# <Axes: >
